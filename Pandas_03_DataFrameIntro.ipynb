# %% [markdown]
# <a href="https://colab.research.google.com/github/csaatechnicalarts/ML_Bootcamp/blob/main/Pandas_03_DataFrameIntro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #03 Pandas Data Structure: Data Frame

# %% [markdown]
# ##Content Outline
#
# * Introducton
# * Relationship between data frames and series
# * Filtering rows and columns
# * Vector operations on data frames
# * Handling date time types
# * Quick note about Numpy

# %% [markdown]
# ## Introduction
# In Pandas, a *data frame* is a two-dimensional structure analogous to tabulated data enclosing rows and columns. The header of a data frame series is known as the *column* while the header of a data frame row is known as an *index*.

# %%
import pandas as pd

# %%
df = pd.read_csv("sample_data/ww2_leaders.csv")
print(f"Type of df: {type(df)}\n")
df
# Out:
# Type of df: <class 'pandas.core.frame.DataFrame'>
#                      Name        Born        Died  Age           Title  \
# 0      Franklin Roosevelt  1882-01-30  1945-04-12   63       President
# 1           Joseph Stalin  1878-12-06  1953-03-05   74    Great Leader
# 2           Adolph Hitler  1889-04-20  1945-04-30   56          Fuhrer
# 3    Michinomiya Hirohito  1901-04-29  1989-01-07   87         Emperor
# 4       Charles de Gaulle  1890-11-22  1970-11-09   79       President
# 5       Winston Churchill  1874-11-30  1965-01-24   90  Prime Minister
# 6          Manuel Camacho  1897-04-24  1955-10-13   58       President
# 7               Jan Smuts  1870-05-24  1950-09-11   80  Prime Minister
# 8                Ibn Saud  1875-01-15  1953-11-09   78            King
# 9   Plaek Phibunsongkhram  1897-07-14  1965-06-11   66  Prime Minister
# 10            John Curtin  1885-01-08  1945-07-05   60  Prime Minister
# 11         Haile Selassie  1892-07-23  1975-08-27   83         Emperor
#
#            Country
# 0    United States
# 1     Soviet Union
# 2          Germany
# 3            Japan
# 4           France
# 5   United Kingdom
# 6           Mexico
# 7     South Africa
# 8     Saudi Arabia
# 9         Thailand
# 10       Australia
# 11        Ethiopia

# %% [markdown]
# In our input file for heads of state during World War 2, **["Name", "Born", "Died", "Age", "Title", "Country"]** make up the list of data frame columns. By default Pandas supplies the indices, labeling the row headers from zero onwards.

# %% [markdown]
# Pandas allows us to isolate specific rows and columns.

# %%
df['Name']
# Out:
# 0        Franklin Roosevelt
# 1             Joseph Stalin
# 2             Adolph Hitler
# 3      Michinomiya Hirohito
# 4         Charles de Gaulle
# 5         Winston Churchill
# 6            Manuel Camacho
# 7                 Jan Smuts
# 8                  Ibn Saud
# 9     Plaek Phibunsongkhram
# 10              John Curtin
# 11           Haile Selassie
# Name: Name, dtype: object

# %%
df.loc[10]
# Out:
# Name          John Curtin
# Born           1885-01-08
# Died           1945-07-05
# Age                    60
# Title      Prime Minister
# Country         Australia
# Name: 10, dtype: object

# %% [markdown]
# ## Relationship Between Data Frames and Series
# In most Pandas tutorials, an individual column in a data frame is a Pandas *series*. But we have to more flexible with that definition, as Pandas reports both the type of a row and the type of a column as *series*. It's probably best to think of a series as a vector of data -- heterogenous data in a row, and homogeneous data in a column -- with an attached header, called "index" and "column".

# %%
print(type(df['Name']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(df.loc[0]))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# We can create a Pandas data frame from using Python dictionaries. Conceptually, the dictionary key becomes the data frame column label and the dictionary value becomes the collection of column values. In practice, we use Pandas series to provison a column, with data and (optionally) the index label that comes with it.

# %%
leader_name_series = pd.Series(["Franklin Roosevelt", "Joseph Stalin", "Adolph Hitler"])
leader_age_series = pd.Series([63, 74, 56])
leader_country_series = pd.Series(["United States", "Soviet Union", "Germany"])
leader_df = pd.DataFrame({"Name": leader_name_series, "Age": leader_age_series, "Country": leader_country_series})
leader_df
# Out:
#                  Name  Age        Country
# 0  Franklin Roosevelt   63  United States
# 1       Joseph Stalin   74   Soviet Union
# 2       Adolph Hitler   56        Germany

# %%
print(f"Type of leader_df: {type(leader_df)}")
# Out:
# Type of leader_df: <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# Pandas handles the cases where the shape of the columnar series do not line up. In our example below, the two series have indices that line up, but their data don't. When creating the data frame, Pandas makes up for the incongruity by slotting **NaN** in the missing data for **col02**.

# %%
col01_series = pd.Series(["aaa", "bbb", "ccc", "ddd", "eee"], index = ["row01", "row02", "row03", "row04", "row05"])
col02_series = pd.Series([100, 200, 300], index = ["row02", "row03", "row05"])
string_int_df = pd.DataFrame({"col01": col01_series, "col02": col02_series})
string_int_df
# Out:
#       col01  col02
# row01   aaa    NaN
# row02   bbb  100.0
# row03   ccc  200.0
# row04   ddd    NaN
# row05   eee  300.0

# %% [markdown]
# ## Filtering Rows and Columns
# Let's head back to our World War 2 leaders data frame.
#
# ---

# %%
df = pd.read_csv("sample_data/ww2_leaders.csv")
print(f"Type of df: {type(df)}\n")
df
# Out:
# Type of df: <class 'pandas.core.frame.DataFrame'>
#                      Name        Born        Died  Age           Title  \
# 0      Franklin Roosevelt  1882-01-30  1945-04-12   63       President
# 1           Joseph Stalin  1878-12-06  1953-03-05   74    Great Leader
# 2           Adolph Hitler  1889-04-20  1945-04-30   56          Fuhrer
# 3    Michinomiya Hirohito  1901-04-29  1989-01-07   87         Emperor
# 4       Charles de Gaulle  1890-11-22  1970-11-09   79       President
# 5       Winston Churchill  1874-11-30  1965-01-24   90  Prime Minister
# 6          Manuel Camacho  1897-04-24  1955-10-13   58       President
# 7               Jan Smuts  1870-05-24  1950-09-11   80  Prime Minister
# 8                Ibn Saud  1875-01-15  1953-11-09   78            King
# 9   Plaek Phibunsongkhram  1897-07-14  1965-06-11   66  Prime Minister
# 10            John Curtin  1885-01-08  1945-07-05   60  Prime Minister
# 11         Haile Selassie  1892-07-23  1975-08-27   83         Emperor
#
#            Country
# 0    United States
# 1     Soviet Union
# 2          Germany
# 3            Japan
# 4           France
# 5   United Kingdom
# 6           Mexico
# 7     South Africa
# 8     Saudi Arabia
# 9         Thailand
# 10       Australia
# 11        Ethiopia

# %% [markdown]
# We can pick a column to filter the data frame rows. For example, say we want to isolate the rows of leaders whose age is less than or equal to the average age for the whole data set. We do so by means of the **[ ]** operator, passing a filtering statement within.

# %%
df.describe()
# Out:
#              Age
# count  12.000000
# mean   72.833333
# std    11.784684
# min    56.000000
# 25%    62.250000
# 50%    76.000000
# 75%    80.750000
# max    90.000000

# %%
df[df['Age'] <= df['Age'].mean()]
# Out:
#                      Name        Born        Died  Age           Title  \
# 0      Franklin Roosevelt  1882-01-30  1945-04-12   63       President
# 2           Adolph Hitler  1889-04-20  1945-04-30   56          Fuhrer
# 6          Manuel Camacho  1897-04-24  1955-10-13   58       President
# 9   Plaek Phibunsongkhram  1897-07-14  1965-06-11   66  Prime Minister
# 10            John Curtin  1885-01-08  1945-07-05   60  Prime Minister
#
#           Country
# 0   United States
# 2         Germany
# 6          Mexico
# 9        Thailand
# 10      Australia

# %% [markdown]
# Behind the scenes the statement **df['Age'] <= df['Age'].mean()** evaluates to a list of boolean values which Pandas uses to filter the data frame rows.

# %% [markdown]
# We can manually create the vector of booleans ourselves to filter the data frame without referencing any column.

# %%
potentates = [False, True, True, True, False, False, False, False, True, False, False, True]
df[potentates]
# Out:
#                     Name        Born        Died  Age         Title  \
# 1          Joseph Stalin  1878-12-06  1953-03-05   74  Great Leader
# 2          Adolph Hitler  1889-04-20  1945-04-30   56        Fuhrer
# 3   Michinomiya Hirohito  1901-04-29  1989-01-07   87       Emperor
# 8               Ibn Saud  1875-01-15  1953-11-09   78          King
# 11        Haile Selassie  1892-07-23  1975-08-27   83       Emperor
#
#          Country
# 1   Soviet Union
# 2        Germany
# 3          Japan
# 8   Saudi Arabia
# 11      Ethiopia

# %%
democratic_leaders = list(map(lambda x: not x, potentates))
df[democratic_leaders]
# Out:
#                      Name        Born        Died  Age           Title  \
# 0      Franklin Roosevelt  1882-01-30  1945-04-12   63       President
# 4       Charles de Gaulle  1890-11-22  1970-11-09   79       President
# 5       Winston Churchill  1874-11-30  1965-01-24   90  Prime Minister
# 6          Manuel Camacho  1897-04-24  1955-10-13   58       President
# 7               Jan Smuts  1870-05-24  1950-09-11   80  Prime Minister
# 9   Plaek Phibunsongkhram  1897-07-14  1965-06-11   66  Prime Minister
# 10            John Curtin  1885-01-08  1945-07-05   60  Prime Minister
#
#            Country
# 0    United States
# 4           France
# 5   United Kingdom
# 6           Mexico
# 7     South Africa
# 9         Thailand
# 10       Australia

# %% [markdown]
# ## Vector Operations on Data Frames
# We can also perform vectorized operations on data frames. In the following example, multiplying by two doubles the values in every numeric cell. Similarly, strings are concatenated with each other, as per the rules in Python.

# %%
df * 2
# Out:
#                                           Name                  Born  \
# 0         Franklin RooseveltFranklin Roosevelt  1882-01-301882-01-30
# 1                   Joseph StalinJoseph Stalin  1878-12-061878-12-06
# 2                   Adolph HitlerAdolph Hitler  1889-04-201889-04-20
# 3     Michinomiya HirohitoMichinomiya Hirohito  1901-04-291901-04-29
# 4           Charles de GaulleCharles de Gaulle  1890-11-221890-11-22
# 5           Winston ChurchillWinston Churchill  1874-11-301874-11-30
# 6                 Manuel CamachoManuel Camacho  1897-04-241897-04-24
# 7                           Jan SmutsJan Smuts  1870-05-241870-05-24
# 8                             Ibn SaudIbn Saud  1875-01-151875-01-15
# 9   Plaek PhibunsongkhramPlaek Phibunsongkhram  1897-07-141897-07-14
# 10                      John CurtinJohn Curtin  1885-01-081885-01-08
# 11                Haile SelassieHaile Selassie  1892-07-231892-07-23
#
#                     Died  Age                         Title  \
# 0   1945-04-121945-04-12  126            PresidentPresident
# 1   1953-03-051953-03-05  148      Great LeaderGreat Leader
# 2   1945-04-301945-04-30  112                  FuhrerFuhrer
# 3   1989-01-071989-01-07  174                EmperorEmperor
# 4   1970-11-091970-11-09  158            PresidentPresident
# 5   1965-01-241965-01-24  180  Prime MinisterPrime Minister
# 6   1955-10-131955-10-13  116            PresidentPresident
# 7   1950-09-111950-09-11  160  Prime MinisterPrime Minister
# 8   1953-11-091953-11-09  156                      KingKing
# 9   1965-06-111965-06-11  132  Prime MinisterPrime Minister
# 10  1945-07-051945-07-05  120  Prime MinisterPrime Minister
# 11  1975-08-271975-08-27  166                EmperorEmperor
#
#                          Country
# 0     United StatesUnited States
# 1       Soviet UnionSoviet Union
# 2                 GermanyGermany
# 3                     JapanJapan
# 4                   FranceFrance
# 5   United KingdomUnited Kingdom
# 6                   MexicoMexico
# 7       South AfricaSouth Africa
# 8       Saudi ArabiaSaudi Arabia
# 9               ThailandThailand
# 10            AustraliaAustralia
# 11              EthiopiaEthiopia

# %% [markdown]
# ## Handling Date and Time Types
# Our information about World War 2 leaders presents a good opportunity to discuss date and time types in Pandas. Right now the **Born** and **Died** columns are of type *object*, which is essentially of type *string*. To carry out operations on these, we first need to convert them to *Timestamp* types. We accomplish this using the Pandas *to_datetime()* method.

# %%
born_dt = pd.to_datetime(df.Born, format = '%Y-%m-%d')
print(f"Type of born_dt: {type(born_dt)}\nType of each born_dt element: {type(born_dt[0])}")
# Out:
# Type of born_dt: <class 'pandas.core.series.Series'>
# Type of each born_dt element: <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# The *to_datetime()* method returns a series of time stamps. The *dtype* is *datetime64* which allows us to apply arithmetic operations on these time stamps.

# %%
born_dt
# Out:
# 0    1882-01-30
# 1    1878-12-06
# 2    1889-04-20
# 3    1901-04-29
# 4    1890-11-22
# 5    1874-11-30
# 6    1897-04-24
# 7    1870-05-24
# 8    1875-01-15
# 9    1897-07-14
# 10   1885-01-08
# 11   1892-07-23
# Name: Born, dtype: datetime64[ns]

# %% [markdown]
# Up till now we haven't showed how to update data frames. Let's now create a new recalculate the age of a leader and append these as a new column to our data frame. To preserve our original data frame, lets make a distinct copy before we proceed.

# %%
df_copy = df.copy()
df_copy['Born_DT'] = born_dt
died_dt = pd.to_datetime(df.Died, format = '%Y-%m-%d')
df_copy['Died_DT'] = died_dt
df_copy
# Out:
#                      Name        Born        Died  Age           Title  \
# 0      Franklin Roosevelt  1882-01-30  1945-04-12   63       President
# 1           Joseph Stalin  1878-12-06  1953-03-05   74    Great Leader
# 2           Adolph Hitler  1889-04-20  1945-04-30   56          Fuhrer
# 3    Michinomiya Hirohito  1901-04-29  1989-01-07   87         Emperor
# 4       Charles de Gaulle  1890-11-22  1970-11-09   79       President
# 5       Winston Churchill  1874-11-30  1965-01-24   90  Prime Minister
# 6          Manuel Camacho  1897-04-24  1955-10-13   58       President
# 7               Jan Smuts  1870-05-24  1950-09-11   80  Prime Minister
# 8                Ibn Saud  1875-01-15  1953-11-09   78            King
# 9   Plaek Phibunsongkhram  1897-07-14  1965-06-11   66  Prime Minister
# 10            John Curtin  1885-01-08  1945-07-05   60  Prime Minister
# 11         Haile Selassie  1892-07-23  1975-08-27   83         Emperor
#
#            Country    Born_DT    Died_DT
# 0    United States 1882-01-30 1945-04-12
# 1     Soviet Union 1878-12-06 1953-03-05
# 2          Germany 1889-04-20 1945-04-30
# 3            Japan 1901-04-29 1989-01-07
# 4           France 1890-11-22 1970-11-09
# 5   United Kingdom 1874-11-30 1965-01-24
# 6           Mexico 1897-04-24 1955-10-13
# 7     South Africa 1870-05-24 1950-09-11
# 8     Saudi Arabia 1875-01-15 1953-11-09
# 9         Thailand 1897-07-14 1965-06-11
# 10       Australia 1885-01-08 1945-07-05
# 11        Ethiopia 1892-07-23 1975-08-27

# %% [markdown]
# Just as with adding new entries in Python dictionaries, we've now extended our data frame with the two new columns with *Timestamp* types. From here we can calculate the leader's age and apply it to a third new column, first as days then finally recalculated as years.

# %%
age_dt = died_dt - born_dt
print(age_dt)
# Out:
# 0    23082 days
# 1    27117 days
# 2    20463 days
# 3    32030 days
# 4    29206 days
# 5    32927 days
# 6    21355 days
# 7    29329 days
# 8    28787 days
# 9    24803 days
# 10   22092 days
# 11   30349 days
# dtype: timedelta64[ns]

# %%
df_copy["Age_DT"] = age_dt // pd.Timedelta('365 days')
df_copy
# Out:
#                      Name        Born        Died  Age           Title  \
# 0      Franklin Roosevelt  1882-01-30  1945-04-12   63       President
# 1           Joseph Stalin  1878-12-06  1953-03-05   74    Great Leader
# 2           Adolph Hitler  1889-04-20  1945-04-30   56          Fuhrer
# 3    Michinomiya Hirohito  1901-04-29  1989-01-07   87         Emperor
# 4       Charles de Gaulle  1890-11-22  1970-11-09   79       President
# 5       Winston Churchill  1874-11-30  1965-01-24   90  Prime Minister
# 6          Manuel Camacho  1897-04-24  1955-10-13   58       President
# 7               Jan Smuts  1870-05-24  1950-09-11   80  Prime Minister
# 8                Ibn Saud  1875-01-15  1953-11-09   78            King
# 9   Plaek Phibunsongkhram  1897-07-14  1965-06-11   66  Prime Minister
# 10            John Curtin  1885-01-08  1945-07-05   60  Prime Minister
# 11         Haile Selassie  1892-07-23  1975-08-27   83         Emperor
#
#            Country    Born_DT    Died_DT  Age_DT
# 0    United States 1882-01-30 1945-04-12      63
# 1     Soviet Union 1878-12-06 1953-03-05      74
# 2          Germany 1889-04-20 1945-04-30      56
# 3            Japan 1901-04-29 1989-01-07      87
# 4           France 1890-11-22 1970-11-09      80
# 5   United Kingdom 1874-11-30 1965-01-24      90
# 6           Mexico 1897-04-24 1955-10-13      58
# 7     South Africa 1870-05-24 1950-09-11      80
# 8     Saudi Arabia 1875-01-15 1953-11-09      78
# 9         Thailand 1897-07-14 1965-06-11      67
# 10       Australia 1885-01-08 1945-07-05      60
# 11        Ethiopia 1892-07-23 1975-08-27      83

# %% [markdown]
# ## Quick Note About Numpy
# Finally we can create Pandas data frames from numPy array.

# %%
import numpy as np
np_data = np.random.random((4,5))
df = pd.DataFrame(np_data, index = ['Sample_01', 'Sample_02', 'Sample_03', 'Sample_04'], columns = np.arange(1,6))
df
# Out:
#                   1         2         3         4         5
# Sample_01  0.417926  0.084715  0.266714  0.285019  0.959304
# Sample_02  0.293612  0.255032  0.743996  0.430041  0.618243
# Sample_03  0.789823  0.792905  0.674767  0.939707  0.345802
# Sample_04  0.912679  0.169676  0.169665  0.533245  0.842510
